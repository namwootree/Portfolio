# %% [markdown]
# # Setting

# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_absolute_error

import lightgbm as lgb
import gc

# %% [markdown]
# # Load Data

# %%
def csv_to_parquet(csv_path, save_name):
    df = pd.read_csv(csv_path)
    df.to_parquet(f'./{save_name}.parquet')
    del df
    gc.collect()
    print(save_name, 'Done.')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_submission_path = '/content/drive/MyDrive/머신러닝 엔지니어링/데이콘/제주도 도로 교통량 예측/data/sample_submission.csv'
df_train_path = '/content/drive/MyDrive/머신러닝 엔지니어링/데이콘/제주도 도로 교통량 예측/data/df_train_V1.csv'
df_test_path = '/content/drive/MyDrive/머신러닝 엔지니어링/데이콘/제주도 도로 교통량 예측/data/df_test_V1.csv'

# %%
csv_to_parquet(df_train_path, 'train')
csv_to_parquet(df_test_path, 'test')
# Out:
# train Done.
# test Done.

# %%
df_train = pd.read_parquet('./train.parquet')
df_test = pd.read_parquet('./test.parquet')

# %% [markdown]
# # Preprocessing

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291241 entries, 0 to 291240
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             291241 non-null  int64
#  1   base_date              291241 non-null  int64
#  2   day_of_week            291241 non-null  object
#  3   base_hour              291241 non-null  object
#  4   lane_count             291241 non-null  object
#  5   road_rating            291241 non-null  object
#  6   multi_linked           291241 non-null  object
#  7   connect_code           291241 non-null  object
#  8   road_type              291241 non-null  object
#  9   maximum_speed_limit    291241 non-null  object
#  10  weight_restricted      291241 non-null  object
#  11  start_node_name        291241 non-null  object
#  12  end_node_name          291241 non-null  object
#  13  start_latitude         291241 non-null  object
#  14  end_latitude           291241 non-null  object
#  15  start_longitude        291241 non-null  object
#  16  end_longitude          291241 non-null  object
#  17  start_turn_restricted  291241 non-null  object
#  18  end_turn_restricted    291241 non-null  object
#  19  road_name_is_start     291241 non-null  object
#  20  road_name_is_end       291241 non-null  object
#  21  start_2_end            291241 non-null  object
#  22  end_2_start            291241 non-null  object
#  23  coordinate             291241 non-null  object
#  24  week_hour              291241 non-null  object
#  25  imbalanced             291241 non-null  object
#  26  turn                   291241 non-null  object
#  27  rest_time              291241 non-null  object
#  28  time                   291241 non-null  object
#  29  part_4_hour            291241 non-null  object
#  30  part_6_hour            291241 non-null  object
#  31  part_8_hour            291241 non-null  object
#  32  week_2                 291241 non-null  object
#  33  speed_limit_2          291241 non-null  object
#  34  count_2                291241 non-null  object
#  35  coordinate_2           291241 non-null  object
# dtypes: int64(2), object(34)
# memory usage: 80.0+ MB

# %%
df_train.drop(columns='Unnamed: 0', inplace=True)
df_test.drop(columns='Unnamed: 0', inplace=True)

# %%
obj_feat = df_test.dtypes[df_test.dtypes == "object"].index.tolist()
print("Number of Categorical features: ", len(obj_feat))
# Out:
# Number of Categorical features:  34

# %%
for feature in obj_feat:
    df_train[feature] = pd.Series(df_train[feature], dtype="category")
    df_test[feature] = pd.Series(df_test[feature], dtype="category")

# %%
X = df_train.drop(columns='target')
y = df_train['target']

# %% [markdown]
# # LGBM

# %%
num_model = 0

n_KFold = 10
early_stopping_rounds = 100
max_depth=20

ensemble_array = np.zeros(df_test.shape[0])

# %%
kf = KFold(n_splits=n_KFold, shuffle=True, random_state=2022)

for train_index, vaild_index in kf.split(X):
  
  X_train, X_vaild = X.iloc[train_index], X.iloc[vaild_index]
  y_train, y_vaild = y.iloc[train_index], y.iloc[vaild_index]

  print(f'\n----------------- {num_model} 번 모델 학습 -----------------\n')

  LR = lgb.LGBMRegressor(
                         n_estimators=10000,
                         learning_rate=0.19,
                         num_leaves=2^20,
                         max_depth=-1,
                         n_jobs=-1,
                         class_weight='balanced',
                         device='cpu',
                         early_stopping_round=early_stopping_rounds,
                         )

  LR.fit(X_train, y_train,
         eval_set=[(X_train, y_train), (X_vaild, y_vaild)],
         eval_metric='rmse',
         categorical_feature=obj_feat,
         verbose=100,
         )

  y_pred = LR.predict(X_vaild)

  MAE = mean_absolute_error(y_pred, y_vaild)

  print(f'\n{num_model} 번 Model Vaild MAE : {MAE}\n')

  ensemble_array += LR.predict(df_test)/n_KFold

  num_model += 1
# Out:
# ----------------- 0 번 모델 학습 -----------------
#
# Training until validation scores don't improve for 100 rounds.
# [100]	training's l2: 24.8441	training's rmse: 4.98438	valid_1's l2: 32.8392	valid_1's rmse: 5.73055
# [200]	training's l2: 21.0916	training's rmse: 4.59256	valid_1's l2: 29.1108	valid_1's rmse: 5.39544
# [300]	training's l2: 19.2904	training's rmse: 4.39208	valid_1's l2: 27.426	valid_1's rmse: 5.23698
# [400]	training's l2: 18.3332	training's rmse: 4.28173	valid_1's l2: 26.4928	valid_1's rmse: 5.14711
# [500]	training's l2: 17.5226	training's rmse: 4.186	valid_1's l2: 25.7612	valid_1's rmse: 5.07555
# [600]	training's l2: 17.0137	training's rmse: 4.12477	valid_1's l2: 25.3236	valid_1's rmse: 5.03225
# [700]	training's l2: 16.5451	training's rmse: 4.06757	valid_1's l2: 24.9098	valid_1's rmse: 4.99097
# [800]	training's l2: 16.1646	training's rmse: 4.02052	valid_1's l2: 24.612	valid_1's rmse: 4.96105
# [900]	training's l2: 15.8335	training's rmse: 3.97913	valid_1's l2: 24.301	valid_1's rmse: 4.92961
# [1000]	training's l2: 15.5409	training's rmse: 3.9422	valid_1's l2: 24.0693	valid_1's rmse: 4.90605
# [1100]	training's l2: 15.2557	training's rmse: 3.90586	valid_1's l2: 23.8637	valid_1's rmse: 4.88505
# [1200]	training's l2: 15.0029	training's rmse: 3.87336	valid_1's l2: 23.6636	valid_1's rmse: 4.86453
# [1300]	training's l2: 14.7768	training's rmse: 3.84406	valid_1's l2: 23.5035	valid_1's rmse: 4.84805
# [1400]	training's l2: 14.5624	training's rmse: 3.81607	valid_1's l2: 23.3482	valid_1's rmse: 4.832
# [1500]	training's l2: 14.3883	training's rmse: 3.7932	valid_1's l2: 23.2208	valid_1's rmse: 4.81879
# [1600]	training's l2: 14.218	training's rmse: 3.77067	valid_1's l2: 23.1063	valid_1's rmse: 4.8069
# [1700]	training's l2: 14.0641	training's rmse: 3.75021	valid_1's l2: 22.9951	valid_1's rmse: 4.79532
# [1800]	training's l2: 13.9377	training's rmse: 3.73333	valid_1's l2: 22.9097	valid_1's rmse: 4.78641
# [1900]	training's l2: 13.8165	training's rmse: 3.71705	valid_1's l2: 22.8332	valid_1's rmse: 4.77841
# [2000]	training's l2: 13.6713	training's rmse: 3.69748	valid_1's l2: 22.7305	valid_1's rmse: 4.76765
# [2100]	training's l2: 13.5332	training's rmse: 3.67876	valid_1's l2: 22.6485	valid_1's rmse: 4.75905
# [2200]	training's l2: 13.4001	training's rmse: 3.66061	valid_1's l2: 22.5666	valid_1's rmse: 4.75044
# [2300]	training's l2: 13.2727	training's rmse: 3.64317	valid_1's l2: 22.4915	valid_1's rmse: 4.74252
# [2400]	training's l2: 13.1762	training's rmse: 3.62991	valid_1's l2: 22.4353	valid_1's rmse: 4.73659
# [2500]	training's l2: 13.0637	training's rmse: 3.61438	valid_1's l2: 22.3673	valid_1's rmse: 4.7294
# [2600]	training's l2: 12.9666	training's rmse: 3.60091	valid_1's l2: 22.3135	valid_1's rmse: 4.72372
# [2700]	training's l2: 12.8764	training's rmse: 3.58836	valid_1's l2: 22.2678	valid_1's rmse: 4.71888
# [2800]	training's l2: 12.7777	training's rmse: 3.57459	valid_1's l2: 22.2149	valid_1's rmse: 4.71327
# [2900]	training's l2: 12.6967	training's rmse: 3.56324	valid_1's l2: 22.1772	valid_1's rmse: 4.70927
# [3000]	training's l2: 12.6256	training's rmse: 3.55326	valid_1's l2: 22.1419	valid_1's rmse: 4.70552
# [3100]	training's l2: 12.555	training's rmse: 3.5433	valid_1's l2: 22.1102	valid_1's rmse: 4.70215
# [3200]	training's l2: 12.4789	training's rmse: 3.53254	valid_1's l2: 22.0743	valid_1's rmse: 4.69833
# [3300]	training's l2: 12.4014	training's rmse: 3.52156	valid_1's l2: 22.0359	valid_1's rmse: 4.69425
# [3400]	training's l2: 12.3332	training's rmse: 3.51187	valid_1's l2: 22.0021	valid_1's rmse: 4.69064
# [3500]	training's l2: 12.2488	training's rmse: 3.49983	valid_1's l2: 21.9592	valid_1's rmse: 4.68606
# [3600]	training's l2: 12.1823	training's rmse: 3.49032	valid_1's l2: 21.9271	valid_1's rmse: 4.68263
# [3700]	training's l2: 12.11	training's rmse: 3.47994	valid_1's l2: 21.8898	valid_1's rmse: 4.67865
# [3800]	training's l2: 12.0307	training's rmse: 3.46854	valid_1's l2: 21.8483	valid_1's rmse: 4.67422
# [3900]	training's l2: 11.9675	training's rmse: 3.45941	valid_1's l2: 21.8054	valid_1's rmse: 4.66962
# [4000]	training's l2: 11.8944	training's rmse: 3.44883	valid_1's l2: 21.7675	valid_1's rmse: 4.66557
# [4100]	training's l2: 11.8306	training's rmse: 3.43956	valid_1's l2: 21.7369	valid_1's rmse: 4.66229
# [4200]	training's l2: 11.7697	training's rmse: 3.4307	valid_1's l2: 21.707	valid_1's rmse: 4.65907
# [4300]	training's l2: 11.7114	training's rmse: 3.42219	valid_1's l2: 21.6805	valid_1's rmse: 4.65623
# [4400]	training's l2: 11.652	training's rmse: 3.4135	valid_1's l2: 21.6529	valid_1's rmse: 4.65327
# [4500]	training's l2: 11.5994	training's rmse: 3.40578	valid_1's l2: 21.6324	valid_1's rmse: 4.65107
# [4600]	training's l2: 11.536	training's rmse: 3.39646	valid_1's l2: 21.5994	valid_1's rmse: 4.64751
# [4700]	training's l2: 11.4765	training's rmse: 3.38769	valid_1's l2: 21.5659	valid_1's rmse: 4.64391
# [4800]	training's l2: 11.4193	training's rmse: 3.37925	valid_1's l2: 21.533	valid_1's rmse: 4.64037
# [4900]	training's l2: 11.3645	training's rmse: 3.37113	valid_1's l2: 21.5062	valid_1's rmse: 4.63747
# [5000]	training's l2: 11.3104	training's rmse: 3.36309	valid_1's l2: 21.4795	valid_1's rmse: 4.6346
# [5100]	training's l2: 11.2574	training's rmse: 3.35521	valid_1's l2: 21.4522	valid_1's rmse: 4.63165
# [5200]	training's l2: 11.1971	training's rmse: 3.3462	valid_1's l2: 21.4196	valid_1's rmse: 4.62814
# [5300]	training's l2: 11.1453	training's rmse: 3.33846	valid_1's l2: 21.3952	valid_1's rmse: 4.62549
# [5400]	training's l2: 11.0936	training's rmse: 3.33071	valid_1's l2: 21.37	valid_1's rmse: 4.62277
# [5500]	training's l2: 11.0454	training's rmse: 3.32347	valid_1's l2: 21.347	valid_1's rmse: 4.62028
# [5600]	training's l2: 10.9973	training's rmse: 3.31621	valid_1's l2: 21.3257	valid_1's rmse: 4.61798
# [5700]	training's l2: 10.9564	training's rmse: 3.31005	valid_1's l2: 21.3062	valid_1's rmse: 4.61587
# [5800]	training's l2: 10.9169	training's rmse: 3.30408	valid_1's l2: 21.2913	valid_1's rmse: 4.61425
# [5900]	training's l2: 10.8738	training's rmse: 3.29754	valid_1's l2: 21.2731	valid_1's rmse: 4.61228
# [6000]	training's l2: 10.8325	training's rmse: 3.29127	valid_1's l2: 21.2578	valid_1's rmse: 4.61062
# [6100]	training's l2: 10.7875	training's rmse: 3.28443	valid_1's l2: 21.2374	valid_1's rmse: 4.60841
# [6200]	training's l2: 10.7482	training's rmse: 3.27845	valid_1's l2: 21.221	valid_1's rmse: 4.60663
# [6300]	training's l2: 10.7076	training's rmse: 3.27225	valid_1's l2: 21.2039	valid_1's rmse: 4.60476
# [6400]	training's l2: 10.6663	training's rmse: 3.26593	valid_1's l2: 21.1877	valid_1's rmse: 4.60301
# [6500]	training's l2: 10.6242	training's rmse: 3.25948	valid_1's l2: 21.169	valid_1's rmse: 4.60098
# [6600]	training's l2: 10.5857	training's rmse: 3.25357	valid_1's l2: 21.154	valid_1's rmse: 4.59935
# [6700]	training's l2: 10.5435	training's rmse: 3.24707	valid_1's l2: 21.1343	valid_1's rmse: 4.5972
# [6800]	training's l2: 10.5037	training's rmse: 3.24094	valid_1's l2: 21.1186	valid_1's rmse: 4.5955

# %% [markdown]
# # Submission

# %%
sample_submission = pd.read_csv(df_submission_path)

sample_submission.iloc[:,1:] = 0

sample_submission['target'] = ensemble_array

# %%
sample_submission.to_csv("/content/drive/MyDrive/머신러닝 엔지니어링/데이콘/제주도 도로 교통량 예측/data/submission/LGBM_KFold_10_V1_lr_0.16.csv", index = False)

# %%
sample_submission
